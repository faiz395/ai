# %%
graph = {
    'a' : ['b','c'],
    'b' : ['d','e'],
    'c' : ['f','g'],
    'd' : ['h','i'],
    'e' : ['f','j'],
    'f' : ['j'],
    'g' : [],
    'h' : [],
    'i' : [],
    'j' : []
}

# %%
#without goal node
visited = [] #list for visited node
queue = [] #initializing a queue

def bfs(visited, graph, node):
  visited.append(node)
  queue.append(node)
  while queue:
    m = queue.pop(0)
    print(m,end="")
    print("\n")
    for neighbour in graph[m]:
      if neighbour not in visited:
        visited.append(neighbour)
        queue.append(neighbour)

print("Following is the BFS \n")
bfs (visited, graph, 'a')
# Out:
# Following is the BFS
#
# a
#
# b
#
# c
#
# d
#
# e
#
# f
#
# g
#
# h
#
# i
#
# j

# %%
#with goal node
visited = [] #list for visited node
queue = [] #initializing a queue

def bfs(visited, graph, node, gnode):
  visited.append(node)
  queue.append(node)
  while queue:
    m = queue.pop(0)
    print(m,end="")
    print("\n")
    for neighbour in graph[m]:
      if neighbour not in visited:
        if gnode not in visited:
          visited.append(neighbour)
          queue.append(neighbour)

print("Following is the BFS \n")
bfs (visited, graph, 'a', 'f')
# Out:
# Following is the BFS
#
# a
#
# b
#
# c
#
# d
#
# e
#
# f
